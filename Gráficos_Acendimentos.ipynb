# %% [markdown]
# <a href="https://colab.research.google.com/github/iancamleite/qfe/blob/master/Gr%C3%A1ficos_Acendimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/iancamleite/qfe/master/data/data.csv',header=None)
df.head(20)
# Out:
#          0    1    2   3   4   5   ...        23   24   25        26   27   28
# 0   0.00000  0.0  0.0   0   0   0  ... -0.000007  0.0  0.0 -0.000130  0.0  0.0
# 1   0.00001  0.0  0.0   0   0   0  ...  0.000720  0.0  0.0  0.012840  0.0  0.0
# 2   0.00002  0.0  0.0   0   0   0  ...  0.001448  0.0  0.0  0.025855  0.0  0.0
# 3   0.00003  0.0  0.0   0   0   0  ...  0.002176  0.0  0.0  0.038916  0.0  0.0
# 4   0.00004  0.0  0.0   0   0   0  ...  0.002906  0.0  0.0  0.052023  0.0  0.0
# 5   0.00005  0.0  0.0   0   0   0  ...  0.003636  0.0  0.0  0.065175  0.0  0.0
# 6   0.00006  0.0  0.0   0   0   0  ...  0.004367  0.0  0.0  0.078374  0.0  0.0
# 7   0.00007  0.0  0.0   0   0   0  ...  0.005098  0.0  0.0  0.091619  0.0  0.0
# 8   0.00008  0.0  0.0   0   0   0  ...  0.005831  0.0  0.0  0.104910  0.0  0.0
# 9   0.00009  0.0  0.0   0   0   0  ...  0.006564  0.0  0.0  0.118250  0.0  0.0
# 10  0.00010  0.0  0.0   0   0   0  ...  0.007298  0.0  0.0  0.131630  0.0  0.0
# ...

# %%
df.columns = ['Time','Wr','Wrr','Vs1','Vs2','Vs3','Vs1r','Vs2r','Vs3r','Vr1','Vr2','Vr3','Is1','Is2','Is3','Ir1','Ir2','Ir3','Ce','Tm','FluxoR','FluxoRr','IsdB','IsdBr','IsqB','IsqBr','VsdB','VsqB','ang_B']

# %%
#for i, v in enumerate(df.columns):
  #df[v] = df[v].to_string(float_format='{:.20f}'.format)

# %%
df.to_excel('final_data.xlsx')

# %%
from google.colab import files
files.download('final_data.xlsx')
